# %% [markdown]
# ## **Deep Neural Network**

# %%
# IMPORTING DATASET
from keras.datasets import mnist

data = mnist.load_data()

# %% [markdown]
# ### Defining Training and testing data

# %%
(X_train, y_train), (X_test, y_test) = data

# %%
import matplotlib.pyplot as plt

plt.subplot(221)
plt.imshow(X_train[0], cmap=plt.get_cmap('gray'))
plt.subplot(222)
plt.imshow(X_train[1], cmap=plt.get_cmap('gray'))
plt.subplot(223)
plt.imshow(X_train[2], cmap=plt.get_cmap('gray'))
plt.subplot(224)
plt.imshow(X_train[3], cmap=plt.get_cmap('gray'))
# show the plot
plt.show()

# %%
# Shape of Training Data
X_train[0].shape
# Out:
# (28, 28)

# %%
# Reshaping the Training Data
X_train = X_train.reshape((X_train.shape[0], 28*28)).astype('float32')
X_test = X_test.reshape((X_test.shape[0], 28*28)).astype('float32')

# %%
# Normalizing Values from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255

# %%
from keras.utils import np_utils

print(y_test.shape)

y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

num_classes = y_test.shape[1]
print(y_test.shape)
# Out:
# (10000,)
# (10000, 10)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
#Defining Model
model = Sequential()

#Adding First HIdden Layer
model.add(Dense(32, input_dim = 28*28, activation='relu'))

#Adding Second Hidden Layer
model.add(Dense(32, input_dim = 28*28, activation='relu'))

#Adding output layer having 10 neurons 
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# ![dnn-28vmlum.png](data:image/png;base64,...)

# %%
# Compile Model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Print Model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                330
# =================================================================
# Total params: 26,506
# Trainable params: 26,506
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train Model
model.fit(X_train, y_train, epochs=10, batch_size=100)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 2s 2ms/step - loss: 0.4509 - accuracy: 0.8718
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2060 - accuracy: 0.9398
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1651 - accuracy: 0.9511
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1401 - accuracy: 0.9582
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1243 - accuracy: 0.9629
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1129 - accuracy: 0.9664
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1035 - accuracy: 0.9688
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0944 - accuracy: 0.9717
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0884 - accuracy: 0.9729
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0817 - accuracy: 0.9752

# %%
scores = model.evaluate(X_test, y_test)
print(scores) ##return loss and accuracy
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1153 - accuracy: 0.9659
# [0.11530335992574692, 0.9659000039100647]
